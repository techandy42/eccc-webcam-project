# %% [markdown]
# # Class Distribution
#
# > Train Dataset
#
# ```
# MISSING: 94411 -> 94411 (selected 100%)
# RAIN_ONLY: 9575 -> 94411 (copied x10) (Including "DRIZZLE_ONLY", "FREEZING_PRECIP")
# SNOW_ONLY: 21465 -> 94411 (copied x5) (Including "RAIN_AND_SNOW")
# ```
#
# > Test/Validation Dataset
#
# ```
# MISSING: 1000
# RAIN_ONLY: 1000 (Including "DRIZZLE_ONLY", "FREEZING_PRECIP")
# SNOW_ONLY: 1000 (Including "RAIN_AND_SNOW")
# ```

# %% [markdown]
# # Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

file_names = ["reduced_class_test_images"]
folder_names = ["test_images"]

for file_name, folder_name in zip(file_names, folder_names):
  # Path to the ZIP file (could be from your Colab environment or Google Drive)
  zip_file_path = f'/content/drive/My Drive/Webcam_Project/datasets/reduced_class_images/{file_name}.zip'

  # Create target directory if it doesn't exist
  if not os.path.exists(folder_name):
      os.makedirs(folder_name)

  # Unzip the file
  with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
      zip_ref.extractall(folder_name)

  print(f'Files extracted to {folder_name}')
# Out:
# Files extracted to test_images

# %%
CLASS_NAMES = ['MISSING', 'RAIN_ONLY', 'SNOW_ONLY']

# %%
# !find ./test_images/MISSING -maxdepth 1 -type f | wc -l
# !find ./test_images/RAIN_ONLY -maxdepth 1 -type f | wc -l
# !find ./test_images/SNOW_ONLY -maxdepth 1 -type f | wc -l
# Out:
# 1000
# 1000
# 1000

# %% [markdown]
# # Running Model

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim

# %%
from torchvision import datasets, transforms
import torch
from torch.utils.data import DataLoader

# Define your transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)), # Resize the image to 224x224 pixels
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize([0.485, 0.456, 0.406], # Normalize using ImageNet mean and std
                         [0.229, 0.224, 0.225])
])

# %%
# Define the dataset using ImageFolder
test_dataset = datasets.ImageFolder(root='test_images/', transform=transform)

# %%
# Create DataLoaders
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
from torchvision import models
import torch.nn as nn

# Load pre-trained MobileNetV2
model = models.mobilenet_v2(pretrained=True)

# Number of features in the last layer of the model
num_ftrs = model.classifier[1].in_features

# Adjust the classifier to your number of classes
# Replace `num_classes` with the actual number of classes
num_classes = len(CLASS_NAMES)  # Assuming 'dataset' is your ImageFolder dataset
model.classifier[1] = nn.Linear(num_ftrs, num_classes)

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 158MB/s]

# %%
# Path to your saved model weights
model_weights_path = f'/content/drive/My Drive/Webcam_Project/model_weights/new_models/mobilenetv2_model_weights.pth'

# Load the weights into the model
model.load_state_dict(torch.load(model_weights_path, map_location=device))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Running Inference

# %%
# Validation phase
model.eval()  # Set model to evaluation mode
correct = 0
total = 0
with torch.no_grad():  # No gradients needed
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

acc = 100 * correct / total

print(f'Test Accuracy: {acc:.2f}%')
# Out:
# Test Accuracy: 84.20%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools

class_names = ["No Precipitation", "Rain", "Snow"]

model.eval()  # Set model to evaluation mode
all_preds = []
all_labels = []

with torch.no_grad():  # No gradients needed
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Compute the confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Plotting the confusion matrix
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names, ax=ax)
ax.set_xlabel('Predicted Labels')
ax.set_ylabel('True Labels')
ax.set_title('Confusion Matrix')
plt.show()

# %%
# Calculate class accuracies from the confusion matrix
class_accuracies = cm.diagonal() / cm.sum(axis=1)

# Print class accuracies
print("Accuracy per class:")
for class_name, accuracy in zip(class_names, class_accuracies):
    print(f"{class_name}: {accuracy * 100:.2f}%")
# Out:
# Accuracy per class:
# No Precipitation: 85.50%
# Rain: 82.00%
# Snow: 85.10%

# %% [markdown]
# # Match Rain (>= 3 deg) and Snow (<= -1 deg)

# %% [markdown]
# Measurements:
# - For Precipitations (Rain or Snow)
# - TP / Total for each Rain and Snow

# %%
provincial_code = ['AB', 'BC', 'MB', 'NF', 'NS', 'NT', 'NU', 'ON', 'QC', 'YT']
provincial_report = [code + '_ASOS_Matched.csv' for code in provincial_code]

# %%
import pandas as pd
import os

reports = {}

for report, code in zip(provincial_report, provincial_code):
    reports[code] = pd.read_csv(f"/content/drive/My Drive/Webcam_Project/Provincial_Matched/{report}")
# Out:
# <ipython-input-19-1d6ff0ce3159>:7: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports[code] = pd.read_csv(f"/content/drive/My Drive/Webcam_Project/Provincial_Matched/{report}")
# <ipython-input-19-1d6ff0ce3159>:7: DtypeWarning: Columns (2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports[code] = pd.read_csv(f"/content/drive/My Drive/Webcam_Project/Provincial_Matched/{report}")
# <ipython-input-19-1d6ff0ce3159>:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports[code] = pd.read_csv(f"/content/drive/My Drive/Webcam_Project/Provincial_Matched/{report}")
# <ipython-input-19-1d6ff0ce3159>:7: DtypeWarning: Columns (2,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports[code] = pd.read_csv(f"/content/drive/My Drive/Webcam_Project/Provincial_Matched/{report}")

# %%
report_comb = pd.concat([reports[code] for code in reports.keys()], keys=list(reports.keys()))

# %%
report_comb.head()
# Out:
#      station             valid  tmpc    dwpc   relh    drct  sknt     mslp  \
# AB 0    CYQF  2022-12-16 00:00  -8.0  -11.00  79.00  240.00  5.00  1032.60
#    1    CYQL  2022-12-16 00:00  -6.0   -9.00  79.31  250.00  4.00  1034.00
#    2    CYLL  2022-12-16 00:00 -15.0  -17.00  84.68  280.00  6.00  1030.50
#    3    CYOJ  2022-12-16 00:00 -12.0  -13.00  92.25  180.00  2.00  1028.70
#    4    CYZU  2022-12-16 00:00  -4.0   -7.00  79.62  290.00  4.00  1030.40
#
#       p01m   vsby  ...   Hail     GS     IP     DZ FZRA/FZDZ  \
# AB 0   0.0   9.00  ...  False  False  False  False     False
#    1   0.0  25.00  ...  False  False  False  False     False
#    2   0.0   6.00  ...  False  False  False  False     False
#    3   0.0  10.00  ...  False  False  False  False     False
#    4   0.0  15.00  ...  False  False  False  False     False
#
#      precipitation_category             valid_dt matched_image_file  \
# AB 0                MISSING  2022-12-16 00:00:00                NaN
#    1                MISSING  2022-12-16 00:00:00                NaN
#    2                    NaN  2022-12-16 00:00:00                NaN
#    3              SNOW_ONLY  2022-12-16 00:00:00                NaN
#    4                MISSING  2022-12-16 00:00:00                NaN
#
#      matched_image_folder p01i
# AB 0                  NaN  NaN
#    1                  NaN  NaN
#    2                  NaN  NaN
#    3                  NaN  NaN
#    4                  NaN  NaN
#
# [5 rows x 35 columns]

# %%
report_comb['precipitation_category'].unique()
# Out:
# array(['MISSING', nan, 'SNOW_ONLY', 'RAIN_ONLY', 'RAIN_AND_SNOW', 'ICE',
#        'DRIZZLE_ONLY', 'FREEZING_PRECIP'], dtype=object)

# %%
model.eval()  # Set model to evaluation mode
filename_pred_class_map = {}

with torch.no_grad():  # No gradients needed
    for i, (inputs, labels) in enumerate(test_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        predicted_classes = [class_names[pred] for pred in predicted.cpu().numpy()]

        # Assuming test_loader's batch size is constant and samples are not shuffled
        # If there's shuffling, you'll need the actual indices of samples in the batch
        batch_start = i * test_loader.batch_size
        batch_filenames = [filename for filename, _ in test_dataset.samples[batch_start:batch_start+len(inputs)]]

        # Store the filename: predicted class mapping
        for filename, predicted_class in zip(batch_filenames, predicted_classes):
            filename = '-'.join(filename.split('/')[-1].split('.jpg')[0].split('-')[:-1]) + '.jpg'
            filename_pred_class_map[filename] = predicted_class

# At this point, filename_pred_class_map contains the mapping you wanted

# %%
filename_pred_class_map
# Out:
# {'CYAB-SE-2023_03_31-15_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_03_31-19_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_04_12-14_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_04_28-17_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_05_16-12_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_05_17-18_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_05_29-19_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_06_05-18_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_07_05-14_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_07_28-19_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_08_07-12_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_08_08-19_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_08_21-15_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_09_19-13_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_09_20-20_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_09_28-13_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_10_04-17_54_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_11_01-15_04_30.jpg': 'No Precipitation',
#  'CYAB-SE-2023_11_18-19_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_01_02-17_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_01_03-19_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_03_01-00_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_04_04-18_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_05_03-18_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_05_09-01_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_05_29-18_54_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_05_30-18_54_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_06_09-18_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_08_09-23_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_08_21-16_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_09_06-18_54_30.jpg': 'Rain',
#  'CYBD-SW-2023_09_10-21_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_09_14-22_54_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_09_22-00_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_09_29-22_54_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_10_11-22_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_10_14-20_54_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_10_21-19_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_10_24-20_04_30.jpg': 'No Precipitation',
#  'CYBD-SW-2023_12_22-19_34_30.jpg': 'Rain',
#  'CYBD-SW-2024_01_10-22_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_01_18-16_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_01_24-20_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_03_06-20_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_03_17-19_04_30.jpg': 'Snow',
#  'CYBV-W-2023_04_06-21_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_07-20_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_11-16_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_12-17_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_12-20_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_17-15_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_04_26-12_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_06_16-13_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_06_16-15_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_07_27-20_54_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_08_14-14_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_08_14-15_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_08_30-19_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2023_10_05-13_04_30.jpg': 'No Precipitation',
#  'CYBV-W-2024_01_22-18_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_01_06-15_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_01_10-17_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_03_13-11_04_30.jpg': 'Snow',
#  'CYCY-N-2023_04_15-19_04_30.jpg': 'Snow',
#  'CYCY-N-2023_05_01-05_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_07-04_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_10-05_34_30.jpg': 'Snow',
#  'CYCY-N-2023_05_22-14_04_30.jpg': 'Snow',
#  'CYCY-N-2023_05_25-05_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_26-13_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_27-13_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_28-18_14_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_05_31-07_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_06_01-13_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_06_06-17_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_06_16-22_04_30.jpg': 'Rain',
#  'CYCY-N-2023_06_17-20_04_30.jpg': 'Rain',
#  'CYCY-N-2023_06_24-03_34_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_06_24-11_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_06_27-19_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_07-23_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_14-16_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_18-15_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_19-10_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_27-05_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_29-15_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_07_29-23_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_08_06-19_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_08_11-06_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_08_19-13_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_08_29-00_54_30.jpg': 'Rain',
#  'CYCY-N-2023_09_01-17_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_02-18_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_07-23_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_15-21_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_20-15_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_21-11_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_22-17_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_23-14_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_09_24-20_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_10_03-13_44_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_10_03-15_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_10_18-14_24_30.jpg': 'Snow',
#  'CYCY-N-2023_10_19-17_04_30.jpg': 'Snow',
#  'CYCY-N-2023_10_22-11_54_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_11_08-16_04_30.jpg': 'No Precipitation',
#  'CYCY-N-2023_12_27-18_54_30.jpg': 'Snow',
#  'CYCY-N-2024_01_09-18_04_30.jpg': 'Snow',
#  'CYDB-S-2023_01_10-18_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_01_13-19_04_30.jpg': 'Snow',
#  'CYDB-S-2023_03_05-02_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_03_15-18_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_03_28-15_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_03_28-21_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_04_20-00_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_04_27-14_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_04_29-04_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_05_17-20_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_05_24-18_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_05_28-03_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_06_09-23_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_06_28-15_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_06_28-18_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_07_04-21_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_07_10-01_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_07_22-16_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_07_28-19_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_03-14_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_04-13_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_08-01_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_15-02_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_15-15_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_15-17_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_08_29-21_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_09_01-22_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_09_05-18_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_09_30-15_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_01-00_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_11-21_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_12-22_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_13-19_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_23-17_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_10_26-02_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_11_28-21_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_12_03-22_04_30.jpg': 'Snow',
#  'CYDB-S-2023_12_10-19_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2023_12_22-17_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2024_01_02-00_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2024_01_11-18_54_30.jpg': 'No Precipitation',
#  'CYDB-S-2024_01_12-22_04_30.jpg': 'No Precipitation',
#  'CYDB-S-2024_01_22-00_04_30.jpg': 'Snow',
#  'CYFO-SW-2023_01_07-23_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_02_04-17_24_30.jpg': 'Snow',
#  'CYFO-SW-2023_02_09-22_04_30.jpg': 'Snow',
#  'CYFO-SW-2023_02_10-20_54_30.jpg': 'Snow',
#  'CYFO-SW-2023_02_16-17_04_30.jpg': 'Snow',
#  'CYFO-SW-2023_02_16-21_04_30.jpg': 'Snow',
#  'CYFO-SW-2023_02_20-22_04_30.jpg': 'Snow',
#  'CYFO-SW-2023_03_25-18_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_03_26-13_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_03_26-17_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_03_29-13_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_04_14-20_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_04_16-20_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_05_01-23_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_02-19_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_03-21_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_08-15_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_08-17_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_23-16_54_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_25-19_54_30.jpg': 'Rain',
#  'CYFO-SW-2023_06_25-22_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_26-15_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_06_30-16_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_07_09-18_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_07_12-14_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_07_13-21_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_07_24-17_54_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_08_06-22_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_09_26-15_04_30.jpg': 'Rain',
#  'CYFO-SW-2023_09_26-22_54_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_10_13-16_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_10_17-23_04_30.jpg': 'No Precipitation',
#  'CYFO-SW-2023_10_28-13_54_30.jpg': 'Snow',
#  'CYFO-SW-2023_12_16-17_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_01_03-21_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_02_05-23_54_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_02_28-00_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_03_09-23_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_03_14-23_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_04_05-18_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_04_26-16_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_05_01-16_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_05_07-14_34_30.jpg': 'Rain',
#  'CYGE-N-2023_05_10-20_54_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_05_11-16_54_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_05_24-15_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_06_03-22_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_06_07-21_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_06_24-00_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_06_26-13_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_07_06-11_54_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_07_09-17_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_07_12-19_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_07_22-15_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_07_29-15_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_08_01-19_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_08_12-20_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_09_05-14_04_30.jpg': 'Rain',
#  'CYGE-N-2023_09_16-19_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_09_17-00_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_10_17-21_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_10_20-14_24_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_10_30-18_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_11_20-19_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_12_08-19_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2023_12_09-17_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2024_01_07-18_04_30.jpg': 'No Precipitation',
#  'CYGE-N-2024_01_08-17_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_03_02-13_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_03_26-13_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_03_26-14_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_03_26-18_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_04_18-00_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_04_24-22_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_08-03_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_19-03_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_19-06_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_23-07_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_25-08_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_27-08_14_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_27-12_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_05_29-01_14_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_10-23_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_11-02_34_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_12-16_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_13-07_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_14-14_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_22-13_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_23-20_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_06_28-13_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_03-01_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_06-17_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_10-17_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_12-01_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_20-13_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_23-20_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_26-04_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_31-15_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_07_31-19_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_01-14_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_03-03_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_03-08_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_04-12_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_07-02_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_08_11-16_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_09_04-21_04_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_09_17-18_04_30.jpg': 'Rain',
#  'CYHK-SE-2023_09_23-19_14_30.jpg': 'Rain',
#  'CYHK-SE-2023_09_28-22_54_30.jpg': 'No Precipitation',
#  'CYHK-SE-2023_10_04-17_54_30.jpg': 'Snow',
#  'CYHK-SE-2023_11_25-17_04_30.jpg': 'Snow',
#  'CYHZ-NE-2023_01_05-13_04_30.jpg': 'Snow',
#  'CYHZ-NE-2023_01_12-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_02_12-21_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_02_25-22_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_02_27-11_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_03_13-19_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_03_29-10_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_04_12-11_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_04_22-23_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_04_24-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_06_09-16_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_06_20-12_24_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_06_21-13_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_06_24-18_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_07_06-18_54_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_07_13-22_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_07_28-13_24_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_08_04-14_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_08_11-20_34_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_08_13-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_08_14-16_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_08_23-11_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_09_01-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_09_08-14_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_09_23-12_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_09_30-16_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_10_09-15_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_10_10-14_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_10_28-14_54_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_11_08-14_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_11_20-14_44_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_11_21-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_11_25-14_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_12_08-17_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_12_13-13_54_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2023_12_24-18_04_30.jpg': 'No Precipitation',
#  'CYHZ-NE-2024_01_11-18_54_30.jpg': 'Rain',
#  'CYIV-SE-2022_12_20-15_04_30.jpg': 'Snow',
#  'CYIV-SE-2022_12_21-20_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2022_12_28-16_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_01_09-21_34_30.jpg': 'Snow',
#  'CYIV-SE-2023_01_30-18_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_02_02-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_02_24-16_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_02_26-22_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_03_12-22_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_03_20-12_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_03_21-13_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_03_25-22_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_03_28-21_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_04_08-00_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_05_12-23_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_05_15-01_14_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_05_28-14_34_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_05_29-17_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_05_30-17_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_01-18_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_07-19_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_12-20_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_15-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_17-02_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_19-09_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_19-18_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_21-15_04_30.jpg': 'Rain',
#  'CYIV-SE-2023_06_24-13_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_06_27-13_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_07_01-01_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_07_14-01_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_07_16-11_14_30.jpg': 'Rain',
#  'CYIV-SE-2023_07_18-18_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_07_25-12_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_07_26-21_04_30.jpg': 'Rain',
#  'CYIV-SE-2023_07_27-17_04_30.jpg': 'Rain',
#  'CYIV-SE-2023_07_30-03_04_30.jpg': 'Rain',
#  'CYIV-SE-2023_08_03-00_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_08_06-12_24_30.jpg': 'Rain',
#  'CYIV-SE-2023_08_08-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_08_18-16_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_08_20-10_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_08_27-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_09_06-15_14_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_09_06-15_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_09_08-00_14_30.jpg': 'Rain',
#  'CYIV-SE-2023_09_08-21_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_09_19-21_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_14-17_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_17-20_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_27-21_54_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_29-16_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_30-13_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_10_30-14_44_30.jpg': 'Snow',
#  'CYIV-SE-2023_10_31-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_11_07-17_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_11_10-21_24_30.jpg': 'Snow',
#  'CYIV-SE-2023_11_18-20_04_30.jpg': 'Snow',
#  'CYIV-SE-2023_11_22-19_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_11_27-22_04_30.jpg': 'No Precipitation',
#  'CYIV-SE-2023_12_21-14_04_30.jpg': 'Snow',
#  'CYIV-SE-2023_12_31-14_04_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_01_17-20_04_30.jpg': 'Snow',
#  'CYJF-E-2023_04_10-18_04_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_04_11-17_04_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_06_05-13_54_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_07_14-17_04_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_09_12-14_04_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_09_29-14_54_30.jpg': 'No Precipitation',
#  'CYJF-E-2023_09_29-17_54_30.jpg': 'Rain',
#  'CYJF-E-2023_11_30-16_04_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_02_02-15_04_30.jpg': 'Snow',
#  'CYKD-SE-2023_02_17-23_04_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_03_24-17_04_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_04_01-23_04_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_05_06-15_54_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_05_18-17_14_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_08_30-16_04_30.jpg': 'Rain',
#  'CYKD-SE-2023_08_31-21_44_30.jpg': 'Rain',
#  'CYKD-SE-2023_09_09-21_54_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_09_09-22_54_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_10_07-23_04_30.jpg': 'No Precipitation',
#  'CYKD-SE-2023_11_23-17_04_30.jpg': 'Snow',
#  'CYKD-SE-2023_12_07-19_54_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_01_27-19_24_30.jpg': 'Snow',
#  'CYLK-NE-2023_02_01-15_54_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_02_12-23_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_03_15-20_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_03_19-22_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_03_31-20_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_01-00_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_13-22_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_15-18_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_18-18_54_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_21-21_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_23-14_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_04_24-16_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_05_03-15_54_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_06_25-18_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_08_20-14_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_08_22-14_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_08_31-22_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_10_11-14_04_30.jpg': 'No Precipitation',
#  'CYLK-NE-2023_10_31-15_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2022_12_30-16_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_01_20-15_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_01_25-21_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_01_25-22_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_02_13-21_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_02_27-20_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_03_05-19_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_03_28-20_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_04_12-18_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_04_19-00_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_04_19-21_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_04_23-03_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_05_03-20_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_05_04-13_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_05_06-18_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_06_29-19_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_07_03-02_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_07_08-23_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_07_09-01_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_08_16-14_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_08_25-17_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_09_09-17_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_09_26-17_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_10_06-20_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_10_18-16_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_11_02-17_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_11_03-21_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_11_23-22_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_11_27-15_04_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_12_07-20_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_12_15-19_54_30.jpg': 'No Precipitation',
#  'CYLL-NW-2023_12_27-22_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2022_12_23-20_04_30.jpg': 'Snow',
#  'CYOJ-NE-2023_01_24-18_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_01_28-17_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_03_23-00_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_03_26-20_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_04_11-22_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_04_18-13_04_30.jpg': 'Rain',
#  'CYOJ-NE-2023_04_19-02_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_04-14_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_08-17_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_08-23_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_10-00_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_10-13_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_10-18_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_14-20_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_17-11_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_05_24-03_04_30.jpg': 'Rain',
#  'CYOJ-NE-2023_06_05-16_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_07-19_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_08-10_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_11-05_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_13-09_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_16-12_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_06_20-12_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_07_06-20_34_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_07_08-11_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_07_10-18_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_07_28-11_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_07_29-19_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_08_03-12_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_08_19-14_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_08_22-17_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_09_30-16_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_10_24-19_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_11_12-17_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_11_27-19_04_30.jpg': 'Snow',
#  'CYOJ-NE-2023_12_18-19_54_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_12_19-23_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2023_12_30-19_04_30.jpg': 'No Precipitation',
#  'CYOJ-NE-2024_01_11-19_54_30.jpg': 'Snow',
#  'CYQB-SW-2022_12_20-15_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_01_03-20_04_30.jpg': 'Snow',
#  'CYQB-SW-2023_01_04-12_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_01_27-22_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_02_06-19_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_02_09-21_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_02_13-13_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_02_18-16_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_03_24-23_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_03_29-19_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_04_11-23_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_04_17-16_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_04_23-14_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_04_24-14_04_30.jpg': 'Rain',
#  'CYQB-SW-2023_04_27-15_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_05_07-15_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_05_17-10_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_05_24-18_04_30.jpg': 'Rain',
#  'CYQB-SW-2023_05_26-01_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_05_28-11_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_06_04-20_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_06_08-19_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_12-16_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_13-17_44_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_21-00_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_23-13_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_28-22_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_07_30-22_54_30.jpg': 'Rain',
#  'CYQB-SW-2023_08_18-17_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_08_21-14_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_09_03-18_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_09_07-23_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_09_14-11_04_30.jpg': 'Rain',
#  'CYQB-SW-2023_09_14-18_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_09_24-21_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_10_03-16_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_10_15-16_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_10_30-21_04_30.jpg': 'Rain',
#  'CYQB-SW-2023_11_08-22_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_11_11-15_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_11_24-12_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_12_17-14_04_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_12_23-19_54_30.jpg': 'No Precipitation',
#  'CYQB-SW-2023_12_28-21_04_30.jpg': 'Rain',
#  'CYQB-SW-2024_01_18-11_54_30.jpg': 'Snow',
#  'CYQF-W-2022_12_23-23_24_30.jpg': 'Snow',
#  'CYQF-W-2022_12_30-21_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_02_02-22_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_02_07-20_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_02_15-01_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_02_19-01_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_02_22-00_34_30.jpg': 'Snow',
#  'CYQF-W-2023_02_23-23_04_30.jpg': 'Snow',
#  'CYQF-W-2023_03_19-21_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_03_25-21_24_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_04_04-22_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_04_18-23_04_30.jpg': 'Rain',
#  'CYQF-W-2023_04_21-20_34_30.jpg': 'Rain',
#  'CYQF-W-2023_04_22-01_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_04_25-18_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_05_06-13_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_05_07-15_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_05_27-12_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_06_13-20_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_06_20-03_24_30.jpg': 'Rain',
#  'CYQF-W-2023_06_30-21_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_07_01-20_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_07_06-11_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_07_31-01_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_08_03-13_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_08_16-22_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_08_23-17_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_09_01-00_24_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_09_13-13_54_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_09_18-21_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_10_02-22_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_10_04-15_54_30.jpg': 'Rain',
#  'CYQF-W-2023_10_10-19_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_10_19-18_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_11_18-20_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_11_20-19_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_11_24-16_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_11_30-19_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_12_02-16_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_12_11-20_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_12_19-17_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2023_12_21-00_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2024_01_03-00_04_30.jpg': 'No Precipitation',
#  'CYQF-W-2024_01_03-19_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_01_04-20_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_01_31-22_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_02_12-15_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_02_19-17_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_02_27-01_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_03_02-19_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_03_12-20_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_03_17-01_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_03_29-23_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_03_30-13_44_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_04_01-19_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_04_17-21_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_04_26-22_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_04_27-14_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_05_03-21_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_05_07-12_34_30.jpg': 'Rain',
#  'CYQL-SW-2023_05_30-19_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_06_04-12_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_06_07-19_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_06_23-15_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_07_09-17_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_07_17-22_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_08_24-14_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_08_24-19_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_09_08-22_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_09_15-00_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_09_17-13_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_09_21-13_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_09_25-21_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_10_09-22_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_10_20-14_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_10_23-14_44_30.jpg': 'Rain',
#  'CYQL-SW-2023_10_27-17_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_11_07-20_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_11_20-20_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_11_22-21_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_11_25-17_04_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_12_29-23_54_30.jpg': 'No Precipitation',
#  'CYQL-SW-2023_12_30-22_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2022_12_18-16_04_30.jpg': 'Snow',
#  'CYQT-N-2023_01_20-21_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_01_22-16_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_02_09-19_14_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_02_17-18_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_02_22-23_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_02_24-16_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_02_25-15_44_30.jpg': 'Snow',
#  'CYQT-N-2023_03_05-20_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_03_27-22_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_04_07-13_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_04_08-19_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_04_09-19_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_05_24-18_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_05_31-01_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_06_03-21_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_06_06-14_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_06_09-01_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_06_14-01_54_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_06_20-17_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_07_07-12_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_07_15-13_04_30.jpg': 'Rain',
#  'CYQT-N-2023_07_18-15_04_30.jpg': 'Rain',
#  'CYQT-N-2023_08_01-22_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_08_27-21_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_09_14-18_54_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_09_19-23_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_09_27-12_24_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_09_30-18_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_10_02-21_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_10_11-16_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_10_12-15_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_10_19-16_44_30.jpg': 'Rain',
#  'CYQT-N-2023_11_08-15_04_30.jpg': 'Snow',
#  'CYQT-N-2023_11_22-18_04_30.jpg': 'No Precipitation',
#  'CYQT-N-2023_12_06-20_04_30.jpg': 'Snow',
#  'CYQT-N-2024_01_23-15_54_30.jpg': 'Snow',
#  'CYRA-E-2022_12_22-16_44_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_04_10-21_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_04_13-20_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_04_21-17_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_06_12-17_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_06_24-18_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_07_03-19_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_07_04-22_54_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_08_07-23_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_09_06-20_54_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_09_08-23_24_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_09_13-00_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_10_09-22_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_11_22-23_04_30.jpg': 'No Precipitation',
#  'CYRA-E-2023_11_24-16_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2022_12_17-14_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_02_04-19_24_30.jpg': 'Snow',
#  'CYTE-E-2023_03_20-19_04_30.jpg': 'Snow',
#  'CYTE-E-2023_03_24-21_04_30.jpg': 'Snow',
#  'CYTE-E-2023_04_23-01_44_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_04_30-12_54_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_05_06-12_44_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_05_11-03_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_05_24-03_04_30.jpg': 'Snow',
#  'CYTE-E-2023_05_25-09_24_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_05_28-09_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_05_28-17_54_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_08_31-13_04_30.jpg': 'Rain',
#  'CYTE-E-2023_09_19-18_44_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_10_02-16_04_30.jpg': 'Rain',
#  'CYTE-E-2023_10_08-18_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_10_14-13_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_10_15-18_44_30.jpg': 'Rain',
#  'CYTE-E-2023_10_29-14_04_30.jpg': 'No Precipitation',
#  'CYTE-E-2023_11_05-17_04_30.jpg': 'Snow',
#  'CYUX-W-2023_02_10-18_04_30.jpg': 'Snow',
#  'CYUX-W-2023_02_16-20_04_30.jpg': 'Snow',
#  'CYUX-W-2023_03_10-13_04_30.jpg': 'Snow',
#  'CYUX-W-2023_03_22-12_04_30.jpg': 'Snow',
#  'CYUX-W-2023_04_10-17_04_30.jpg': 'Snow',
#  'CYUX-W-2023_04_13-22_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_04_19-21_34_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_05_02-15_34_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_05_08-11_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_05_10-11_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_05_22-12_04_30.jpg': 'Snow',
#  'CYUX-W-2023_05_25-15_54_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_06_17-04_54_30.jpg': 'Rain',
#  'CYUX-W-2023_06_17-14_54_30.jpg': 'Rain',
#  'CYUX-W-2023_06_20-05_54_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_06_23-19_04_30.jpg': 'Rain',
#  'CYUX-W-2023_07_16-09_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_07_18-14_04_30.jpg': 'Rain',
#  'CYUX-W-2023_07_20-03_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_07_22-14_04_30.jpg': 'Rain',
#  'CYUX-W-2023_07_25-17_54_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_07_26-09_54_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_07_26-13_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_07_27-02_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_05-03_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_19-22_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_23-11_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_30-17_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_30-21_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_08_31-01_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_09_19-18_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_10_02-11_44_30.jpg': 'Rain',
#  'CYUX-W-2023_10_27-17_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2023_11_10-19_04_30.jpg': 'No Precipitation',
#  'CYUX-W-2024_01_19-16_04_30.jpg': 'Snow',
#  'CYVM-SW-2022_12_29-15_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_02_03-15_04_30.jpg': 'Snow',
#  'CYVM-SW-2023_02_05-14_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_02_10-15_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_03_02-13_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_04_11-10_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_04_11-11_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_04_14-18_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_04_29-16_54_30.jpg': 'Snow',
#  'CYVM-SW-2023_04_29-22_44_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_05_24-12_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_05_31-23_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_06_01-09_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_06_04-22_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_06_11-10_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_06_25-04_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_06_30-02_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_07_08-05_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_07_09-15_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_07_16-23_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_07_26-05_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_07_31-21_34_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_08_15-12_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_08_31-15_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_09_30-18_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_09_30-19_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_10_08-13_04_30.jpg': 'Snow',
#  'CYVM-SW-2023_10_08-14_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_11_21-16_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_11_28-18_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_12_07-17_54_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_12_09-18_04_30.jpg': 'No Precipitation',
#  'CYVM-SW-2023_12_31-18_04_30.jpg': 'Snow',
#  'CYVR-SW-2023_01_15-21_24_30.jpg': 'Rain',
#  'CYVR-SW-2023_01_29-23_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_02_26-21_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_03_01-17_04_30.jpg': 'Rain',
#  'CYVR-SW-2023_03_13-17_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_03_16-15_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_03_22-23_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_03_24-18_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_03_30-17_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_04_10-21_04_30.jpg': 'Rain',
#  'CYVR-SW-2023_04_19-20_04_30.jpg': 'Rain',
#  'CYVR-SW-2023_04_25-16_54_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_04_25-22_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_05_06-13_54_30.jpg': 'Rain',
#  'CYVR-SW-2023_05_10-17_54_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_05_28-21_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_06_01-02_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_06_14-03_54_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_06_17-14_54_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_06_18-20_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_06_26-22_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_07_07-22_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_07_11-04_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_07_20-15_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_08_03-19_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_08_10-20_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_08_26-01_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_08_26-19_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_08_31-21_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_09_04-21_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_09_05-01_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_09_05-22_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_09_08-18_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_09_10-22_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_10_20-20_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_10_31-01_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_11_01-23_54_30.jpg': 'No Precipitation',
#  'CYVR-SW-2023_11_09-19_04_30.jpg': 'No Precipitation',
#  'CYVR-SW-2024_01_21-22_04_30.jpg': 'Rain',
#  'CYWK-W-2023_01_21-16_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_02_02-15_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_02_26-20_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_03_22-21_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_04_09-13_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_04_16-12_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_04_18-18_14_30.jpg': 'Rain',
#  'CYWK-W-2023_04_21-13_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_04_26-15_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_05_10-16_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_06_03-00_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_06_04-09_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_06_25-19_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_06_29-18_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_07_04-18_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_07_04-21_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_07_05-16_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_07_18-16_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_07_20-18_04_30.jpg': 'Rain',
#  'CYWK-W-2023_07_25-09_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_08_02-14_04_30.jpg': 'Rain',
#  'CYWK-W-2023_08_03-22_04_30.jpg': 'Rain',
#  'CYWK-W-2023_08_15-19_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_08_24-19_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_08_28-19_54_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_09_03-19_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_09_06-11_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_09_18-13_04_30.jpg': 'Rain',
#  'CYWK-W-2023_09_24-14_54_30.jpg': 'Rain',
#  'CYWK-W-2023_10_25-12_04_30.jpg': 'No Precipitation',
#  'CYWK-W-2023_10_28-12_34_30.jpg': 'Snow',
#  'CYWK-W-2023_11_09-12_04_30.jpg': 'Snow',
#  'CYWK-W-2023_11_18-15_04_30.jpg': 'Snow',
#  'CYWK-W-2023_12_03-16_44_30.jpg': 'Snow',
#  'CYWY-SE-2023_01_16-19_04_30.jpg': 'Snow',
#  'CYWY-SE-2023_01_16-23_04_30.jpg': 'Snow',
#  'CYWY-SE-2023_02_24-21_54_30.jpg': 'Snow',
#  'CYWY-SE-2023_03_07-22_04_30.jpg': 'No Precipitation',
#  'CYWY-SE-2023_03_15-22_04_30.jpg': 'No Precipitation',
#  'CYWY-SE-2023_03_16-19_04_30.jpg': 'Snow',
#  'CYWY-SE-2023_03_17-18_04_30.jpg': 'No Precipitation',
#  'CYWY-SE-2023_03_29-14_04_30.jpg': 'Snow',
#  'CYXP-NE-2023_04_08-14_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_05_16-11_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_05_23-21_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_06_20-21_54_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_08_16-18_54_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_09_02-16_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_09_15-13_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_09_21-18_54_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_10_03-13_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_10_18-11_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_10_26-18_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_10_31-19_54_30.jpg': 'No Precipitation',
#  'CYXP-NE-2023_12_22-15_54_30.jpg': 'Snow',
#  'CYXP-NE-2024_01_07-18_04_30.jpg': 'No Precipitation',
#  'CYXP-NE-2024_01_11-16_54_30.jpg': 'No Precipitation',
#  'CYYB-W-2022_12_17-21_04_30.jpg': 'Snow',
#  'CYYB-W-2023_01_26-20_54_30.jpg': 'Snow',
#  'CYYB-W-2023_01_28-20_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_02_20-18_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_02_26-19_04_30.jpg': 'Snow',
#  'CYYB-W-2023_03_07-18_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_03_09-12_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_03_19-19_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_04_06-22_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_04_10-21_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_05_03-18_54_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_05_08-21_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_05_23-17_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_06_01-01_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_06_04-23_54_30.jpg': 'Rain',
#  'CYYB-W-2023_06_21-18_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_06_23-10_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_06_27-12_04_30.jpg': 'Rain',
#  'CYYB-W-2023_07_23-10_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_01-13_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_06-16_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_06-21_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_17-16_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_19-15_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_08_20-14_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_09_03-00_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_09_08-23_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_10_11-17_04_30.jpg': 'Snow',
#  'CYYB-W-2023_10_12-12_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_10_19-16_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_11_03-16_54_30.jpg': 'Rain',
#  'CYYB-W-2023_11_05-20_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_11_11-21_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_11_17-19_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_11_20-21_04_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_12_13-14_54_30.jpg': 'Snow',
#  'CYYB-W-2023_12_22-16_54_30.jpg': 'No Precipitation',
#  'CYYB-W-2023_12_30-16_24_30.jpg': 'No Precipitation',
#  'CYYB-W-2024_01_23-19_14_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_01_01-00_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_01_05-21_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_01_10-21_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_02_11-01_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_02_27-01_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_03_06-21_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_03_17-22_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_04_02-20_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_04_13-16_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_04_25-16_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_04_30-04_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_03-04_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_03-14_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_05-13_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_16-20_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_20-15_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_22-03_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_28-00_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_05_30-03_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_06_09-03_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_06_10-18_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_06_26-13_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_07_03-18_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_07_09-22_24_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_07_19-00_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_07_24-23_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_08_04-00_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_08_16-13_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_08_18-18_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_09_20-17_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_10_06-18_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_10_08-19_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_10_09-20_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_10_14-15_54_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_10_25-19_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_11_19-18_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_11_29-23_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_12_03-23_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2023_12_16-17_04_30.jpg': 'No Precipitation',
#  'CYYD-SW-2024_01_09-21_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_01_18-17_04_30.jpg': 'Snow',
#  'CYYQ-N-2023_01_18-21_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_03_14-14_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_03_20-21_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_04_19-19_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_05_03-21_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_05_11-16_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_05_23-21_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_05_27-12_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_06_03-18_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_06_05-10_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_06_15-08_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_06_15-12_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_09_16-21_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_09_18-00_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_09_27-15_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_10_04-20_54_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_10_06-23_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_10_30-22_04_30.jpg': 'No Precipitation',
#  'CYYQ-N-2023_12_20-20_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2022_12_21-23_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_01_02-16_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_01_21-23_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_01_29-17_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_02_11-16_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_02_16-19_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_03_12-23_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_03_21-16_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_03_22-18_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_04_06-01_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_04_23-13_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_05_02-14_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_05_25-18_54_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_06_01-19_04_30.jpg': 'Rain',
#  'CYZU-SE-2023_07_03-18_04_30.jpg': 'Rain',
#  'CYZU-SE-2023_07_08-01_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_07_12-16_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_08_01-14_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_08_07-15_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_09_28-01_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_11_27-23_04_30.jpg': 'No Precipitation',
#  'CYZU-SE-2023_12_12-23_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_01_08-22_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_01_28-18_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_02_19-19_44_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_03_21-21_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_03_30-14_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_03_30-18_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_04_17-22_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_05_08-19_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_05_13-14_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_05_18-13_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_05_30-14_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_06_01-19_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_06_02-21_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_06_30-18_04_30.jpg': 'Rain',
#  'CZFA-SE-2023_07_05-23_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_07_06-20_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_07_15-00_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_07_15-01_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_08_13-22_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_08_18-20_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_08_22-14_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_08_28-13_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_08_28-16_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_09_03-21_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_09_23-01_04_30.jpg': 'Rain',
#  'CZFA-SE-2023_10_26-22_04_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_10_28-17_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_12_13-16_54_30.jpg': 'No Precipitation',
#  'CZFA-SE-2023_12_22-21_34_30.jpg': 'No Precipitation',
#  'CZFA-SE-2024_01_19-20_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2022_12_20-22_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_01_19-20_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_01_19-23_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_03_20-21_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_03_21-21_34_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_05_18-21_54_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_05_23-20_04_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_06_01-15_54_30.jpg': 'No Precipitation',
#  'CZFN-W-2023_09_29-22_34_30.jpg': 'Rain',
#  'CZFN-W-2023_11_21-23_04_30.jpg': 'No Precipitation',
#  ...}

# %%
def is_valid_float(string):
  try:
    float(string)
    return True
  except ValueError:
    return False

# %%
import pandas as pd

report_comb_filename_to_tmpc_map = {}

map_precipitation_category = {
    'RAIN_ONLY': 'RAIN_ONLY',
    'SNOW_ONLY': 'SNOW_ONLY',
    'MISSING': 'MISSING',
    'RAIN_AND_SNOW': 'SNOW_ONLY',
    'DRIZZLE_ONLY': 'RAIN_ONLY',
    'FREEZING_PRECIP': 'RAIN_ONLY',
}

for index, row in report_comb.iterrows():
    filename = row['matched_image_file']
    tmpc = row['tmpc']
    precipitation_category = row['precipitation_category']
    prediction_category = None

    if filename in filename_pred_class_map:
        prediction_category = filename_pred_class_map[filename]
    else:
      continue

    if precipitation_category in map_precipitation_category:
        precipitation_category = map_precipitation_category[precipitation_category]
    else:
      continue

    if type(tmpc) == str and is_valid_float(tmpc):
        tmpc = float(tmpc)
    else:
        continue

    if not pd.isna(filename) and not pd.isna(tmpc):
      report_comb_filename_to_tmpc_map[filename] = {'tmpc': tmpc, 'precipitation_category': precipitation_category, 'prediction_category': prediction_category}

# %%
for key in list(report_comb_filename_to_tmpc_map.keys())[:20]:
    print(key, report_comb_filename_to_tmpc_map[key]['tmpc'], report_comb_filename_to_tmpc_map[key]['precipitation_category'], report_comb_filename_to_tmpc_map[key]['prediction_category'])
# Out:
# CYOJ-NE-2023_03_15-17_04_30.jpg -16.0 SNOW_ONLY Snow
# CYQL-SW-2023_03_17-01_04_30.jpg 0.0 MISSING No Precipitation
# CYQF-W-2023_03_19-21_04_30.jpg 1.0 MISSING No Precipitation
# CYZU-SE-2023_03_21-16_04_30.jpg -7.0 MISSING No Precipitation
# CYZU-SE-2023_03_22-18_04_30.jpg 0.0 MISSING No Precipitation
# CYOJ-NE-2023_03_23-00_04_30.jpg 6.0 MISSING No Precipitation
# CYQF-W-2023_03_25-21_24_30.jpg 2.0 MISSING No Precipitation
# CYOJ-NE-2023_03_26-20_04_30.jpg -9.0 MISSING No Precipitation
# CYOJ-NE-2023_03_27-18_04_30.jpg -9.0 SNOW_ONLY No Precipitation
# CYQF-W-2023_03_27-18_54_30.jpg -6.0 SNOW_ONLY Snow
# CYQL-SW-2023_03_27-19_04_30.jpg -5.0 SNOW_ONLY Snow
# CYQL-SW-2023_03_28-01_04_30.jpg -5.0 SNOW_ONLY Rain
# CYLL-NW-2023_03_28-20_54_30.jpg -4.0 MISSING No Precipitation
# CYQL-SW-2023_03_29-23_04_30.jpg 5.0 MISSING No Precipitation
# CYQL-SW-2023_03_30-13_44_30.jpg -5.0 MISSING No Precipitation
# CYQL-SW-2023_04_01-19_04_30.jpg 10.0 MISSING No Precipitation
# CYOJ-NE-2023_04_01-22_04_30.jpg -4.0 SNOW_ONLY Snow
# CYZU-SE-2023_04_02-01_04_30.jpg 6.0 RAIN_ONLY Rain
# CYQL-SW-2023_04_02-21_04_30.jpg 1.0 SNOW_ONLY Snow
# CYQL-SW-2023_04_03-14_54_30.jpg -2.0 SNOW_ONLY Snow

# %%
# Create a dictionary to map index to file name
index_to_filename = {idx: '-'.join(filename.split('/')[-1].split('.jpg')[0].split('-')[:-1]) + '.jpg' for idx, (filename, _) in enumerate(test_dataset.samples)}

# Example usage:
print(index_to_filename[0])  # This will print the file name of the first sample in the dataset
# Out:
# CYAB-SE-2023_03_31-15_04_30.jpg

# %%
print("Filename | Temp | Precip Category | Pred Precip Category")
for filename in list(index_to_filename.values())[:50]:
    if filename in report_comb_filename_to_tmpc_map:
      print(filename, report_comb_filename_to_tmpc_map[filename]['tmpc'], report_comb_filename_to_tmpc_map[filename]['precipitation_category'], report_comb_filename_to_tmpc_map[filename]['prediction_category'])
# Out:
# Filename | Temp | Precip Category | Pred Precip Category
# CYBD-SW-2023_01_02-17_04_30.jpg -1.0 MISSING No Precipitation
# CYBD-SW-2023_01_03-19_04_30.jpg 2.0 MISSING No Precipitation
# CYBD-SW-2023_03_01-00_04_30.jpg 3.0 MISSING No Precipitation
# CYBD-SW-2023_04_04-18_04_30.jpg 6.0 MISSING No Precipitation
# CYBD-SW-2023_05_03-18_04_30.jpg 16.0 MISSING No Precipitation
# CYBD-SW-2023_05_09-01_04_30.jpg 19.0 MISSING No Precipitation
# CYBD-SW-2023_05_29-18_54_30.jpg 17.0 MISSING No Precipitation
# CYBD-SW-2023_05_30-18_54_30.jpg 13.0 MISSING No Precipitation
# CYBD-SW-2023_06_09-18_04_30.jpg 19.0 MISSING No Precipitation
# CYBD-SW-2023_08_09-23_04_30.jpg 18.0 MISSING No Precipitation
# CYBD-SW-2023_08_21-16_04_30.jpg 12.0 MISSING No Precipitation
# CYBD-SW-2023_09_06-18_54_30.jpg 16.0 MISSING Rain
# CYBD-SW-2023_09_10-21_04_30.jpg 21.0 MISSING No Precipitation
# CYBD-SW-2023_09_14-22_54_30.jpg 21.0 MISSING No Precipitation
# CYBD-SW-2023_09_22-00_04_30.jpg 19.0 MISSING No Precipitation
# CYBD-SW-2023_09_29-22_54_30.jpg 15.0 MISSING No Precipitation
# CYBD-SW-2023_10_11-22_04_30.jpg 15.0 MISSING No Precipitation
# CYBD-SW-2023_10_14-20_54_30.jpg 14.0 MISSING No Precipitation
# CYBD-SW-2023_10_21-19_04_30.jpg 9.0 MISSING No Precipitation
# CYBD-SW-2023_10_24-20_04_30.jpg 4.0 MISSING No Precipitation
# CYBV-W-2023_01_18-16_04_30.jpg -18.0 MISSING No Precipitation
# CYBV-W-2023_01_24-20_04_30.jpg -14.0 MISSING No Precipitation
# CYBV-W-2023_03_06-20_04_30.jpg -20.0 MISSING No Precipitation
# CYBV-W-2023_03_17-19_04_30.jpg -11.0 MISSING Snow
# CYBV-W-2023_04_06-21_04_30.jpg -4.0 MISSING No Precipitation
# CYBV-W-2023_04_07-20_04_30.jpg 2.0 MISSING No Precipitation
# CYBV-W-2023_04_11-16_04_30.jpg 6.0 MISSING No Precipitation
# CYBV-W-2023_04_12-17_04_30.jpg 8.0 MISSING No Precipitation
# CYBV-W-2023_04_12-20_04_30.jpg 5.0 MISSING No Precipitation

# %%
num_precip_under_minus_1_deg = 0
num_snow_under_minus_1_deg = 0
num_pred_snow_under_minus_1_deg = 0
num_precip_over_3_deg = 0
num_rain_over_3_deg = 0
num_pred_rain_over_3_deg = 0
num_snow_between_minus_1_and_3_deg = 0
for filename in list(index_to_filename.values()):
    if filename in report_comb_filename_to_tmpc_map:
        tmpc = report_comb_filename_to_tmpc_map[filename]['tmpc']
        precipitation_category = report_comb_filename_to_tmpc_map[filename]['precipitation_category']
        prediction_category = report_comb_filename_to_tmpc_map[filename]['prediction_category']

        if precipitation_category != 'MISSING' and tmpc <= -1:
            num_precip_under_minus_1_deg += 1
            if precipitation_category == 'SNOW_ONLY':
                num_snow_under_minus_1_deg += 1
            if prediction_category == 'SNOW_ONLY':
                num_pred_snow_under_minus_1_deg += 1
        elif precipitation_category != 'MISSING' and tmpc >= 3:
            num_precip_over_3_deg += 1
            if precipitation_category == 'RAIN_ONLY':
                num_rain_over_3_deg += 1
            if prediction_category == 'RAIN_ONLY':
                num_pred_rain_over_3_deg += 1

# %%
print(f"Actual percentage of Snow / Snow + Rain (All Precip) under -1 deg: {((num_snow_under_minus_1_deg / num_precip_under_minus_1_deg) * 100):.2f}")
print(f"Predicted percentage of Snow / Snow + Rain (All Precip) under -1 deg: {((num_pred_snow_under_minus_1_deg / num_precip_under_minus_1_deg) * 100):.2f}")
print(f"Actual percentage of Rain / Snow + Rain (All Precip) over 3 deg: {((num_rain_over_3_deg / num_precip_over_3_deg) * 100):.2f}")
print(f"Predicted percentage of Rain / Snow + Rain (All Precip) over 3 deg: {((num_pred_rain_over_3_deg / num_precip_over_3_deg) * 100):.2f}")
# Out:
# Actual percentage of Snow / Snow + Rain (All Precip) under -1 deg: 100.00
# Predicted percentage of Snow / Snow + Rain (All Precip) under -1 deg: 87.84
# Actual percentage of Rain / Snow + Rain (All Precip) over 3 deg: 99.65
# Predicted percentage of Rain / Snow + Rain (All Precip) over 3 deg: 82.81
